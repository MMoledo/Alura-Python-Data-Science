# %%
import numpy as np

# %%
with open('apples_ts.csv','r') as f:
    primeira_linha = f.readline().split(',')


url = 'https://raw.githubusercontent.com/alura-cursos/numpy/dados/apples_ts.csv'


dado = np.loadtxt('apples_ts.csv',delimiter=',',usecols=np.arange(1,88,1))

# %%
dado.ndim

dado.size
# Out:
# 522

# %%
dado.shape
# Out:
# (6, 87)

# %%
dado = dado.T

# %%
datas = dado[:,0]
datas
# Out:
# array([ 1.2013,  2.2013,  3.2013,  4.2013,  5.2013,  6.2013,  7.2013,
#         8.2013,  9.2013, 10.2013, 11.2013, 12.2013,  1.2014,  2.2014,
#         3.2014,  4.2014,  5.2014,  6.2014,  7.2014,  8.2014,  9.2014,
#        10.2014, 11.2014, 12.2014,  1.2015,  2.2015,  3.2015,  4.2015,
#         5.2015,  6.2015,  7.2015,  8.2015,  9.2015, 10.2015, 11.2015,
#        12.2015,  1.2016,  2.2016,  3.2016,  4.2016,  5.2016,  6.2016,
#         7.2016,  8.2016,  9.2016, 10.2016, 11.2016, 12.2016,  1.2017,
#         2.2017,  3.2017,  4.2017,  5.2017,  6.2017,  7.2017,  8.2017,
#         9.2017, 10.2017, 11.2017, 12.2017,  1.2018,  2.2018,  3.2018,
#         4.2018,  5.2018,  6.2018,  7.2018,  8.2018,  9.2018, 10.2018,
#        11.2018, 12.2018,  1.2019,  2.2019,  3.2019,  4.2019,  5.2019,
#         6.2019,  7.2019,  8.2019,  9.2019, 10.2019, 11.2019, 12.2019,
#         1.202 ,  2.202 ,  3.202 ])

# %%
preco = dado[:,1:6]
preco
# Out:
# array([[ 79.72,  42.67,  62.55,  48.26,  71.25],
#        [ 81.08,  44.37,  62.73,  51.01,  71.35],
#        [ 79.68,  44.73,  63.43,  50.91,  70.9 ],
#        [ 79.8 ,  46.75,  63.83,  53.94,  71.92],
#        [ 80.63,    nan,  66.06,  61.27,  72.91],
#        [ 80.8 ,    nan,  69.22,  65.44,  74.39],
#        [ 80.28,  57.8 ,  72.07,  56.51,  73.1 ],
#        [ 78.99,  62.14,  69.31,  53.  ,  70.24],
#        [ 76.77,  56.76,  65.18,  43.87,  69.12],
#        [ 76.09,  50.85,  62.13,  42.12,  68.98],
#        [ 76.36,  46.43,  64.17,  43.98,  68.58],
#        [ 77.16,  46.73,  65.5 ,  44.66,  69.5 ],
#        [ 77.5 ,  45.85,  66.85,  47.73,  70.14],
#        [ 79.03,  49.25,  68.38,  52.31,  70.58],
#        [ 80.28,  48.14,  68.77,  56.8 ,  70.78],
#        [ 80.05,  49.18,  69.32,  51.15,  72.78],
#        [ 78.11,  49.49,  69.77,  54.63,  72.84],
#        [ 76.9 ,  49.83,  70.17,  55.8 ,  74.74],
#        [ 77.68,  49.14,  70.76,  57.31,  76.43],
# ...

# %%
import matplotlib.pyplot as plt

datas = np.arange(1,88,1)
plt.plot(datas,preco[:,0])
plt.show()

# %%
Moscow = preco[:,0]
Kaliningrad = preco[:,1]
Petersburg = preco[:,2]
Krasnodar = preco[:,3]
Ekaterinburg = preco[:,4]

# %%
Moscow
# Out:
# array([ 79.72,  81.08,  79.68,  79.8 ,  80.63,  80.8 ,  80.28,  78.99,
#         76.77,  76.09,  76.36,  77.16,  77.5 ,  79.03,  80.28,  80.05,
#         78.11,  76.9 ,  77.68,  76.05,  75.53,  73.39,  78.36,  89.16,
#        105.43, 104.82, 101.15,  98.63,  99.96,  97.29,  98.64, 104.26,
#        102.63,  98.64,  97.17,  98.09, 103.07, 110.26, 110.84, 112.28,
#        111.1 , 110.06, 113.7 , 112.88, 102.08,  95.54,  91.33,  89.99,
#         91.44,  93.51,  93.6 ,  93.78,  98.91, 121.76, 129.6 , 127.9 ,
#        114.55, 101.88,  99.09, 103.35, 106.58, 108.  , 114.95, 121.17,
#        122.48, 127.58, 131.89, 129.36, 104.26,  93.45,  92.93,  96.15,
#         99.1 , 103.  , 103.31, 103.01, 107.37, 116.91, 125.29, 123.94,
#        113.03, 102.19,  97.83, 101.07, 103.44, 108.23, 110.28])

# %%
print(Moscow)
Moscow_ano1 = Moscow[0:12] 
Moscow_ano2 = Moscow[12:24]
Moscow_ano3 = Moscow[24:36]
Moscow_ano4 = Moscow[36:48]
# Out:
# [ 79.72  81.08  79.68  79.8   80.63  80.8   80.28  78.99  76.77  76.09
#   76.36  77.16  77.5   79.03  80.28  80.05  78.11  76.9   77.68  76.05
#   75.53  73.39  78.36  89.16 105.43 104.82 101.15  98.63  99.96  97.29
#   98.64 104.26 102.63  98.64  97.17  98.09 103.07 110.26 110.84 112.28
#  111.1  110.06 113.7  112.88 102.08  95.54  91.33  89.99  91.44  93.51
#   93.6   93.78  98.91 121.76 129.6  127.9  114.55 101.88  99.09 103.35
#  106.58 108.   114.95 121.17 122.48 127.58 131.89 129.36 104.26  93.45
#   92.93  96.15  99.1  103.   103.31 103.01 107.37 116.91 125.29 123.94
#  113.03 102.19  97.83 101.07 103.44 108.23 110.28]

# %%
plt.plot(np.arange(1,13,1),Moscow_ano1)
plt.plot(np.arange(1,13,1),Moscow_ano2)
plt.plot(np.arange(1,13,1),Moscow_ano3)
plt.plot(np.arange(1,13,1),Moscow_ano4)
plt.legend(["Ano 1","Ano 2","Ano 3","Ano 4"])
plt.show()

# %%
np.allclose(Moscow_ano3,Moscow_ano4,10)
# Out:
# True

# %%
np.array_equal(Moscow_ano3,Moscow_ano4)
# Out:
# False

# %%
plt.plot(datas,Kaliningrad)

# %%
Kaliningrad
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,    nan,    nan,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
np.isnan(Kaliningrad)
# Out:
# array([False, False, False, False,  True,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
sum(np.isnan(Kaliningrad))
# Out:
# 2

# %%
(Kaliningrad[3]+Kaliningrad[6])/2
# Out:
# 52.275

# %%
np.mean([Kaliningrad[3],Kaliningrad[6]])
# Out:
# 52.275

# %%
print(Kaliningrad)
# Out:
# [ 42.67  44.37  44.73  46.75    nan    nan  57.8   62.14  56.76  50.85
#   46.43  46.73  45.85  49.25  48.14  49.18  49.49  49.83  49.14  63.21
#   61.2   60.34  62.2   74.2   75.32  75.92  72.89  74.85  92.19  99.7
#  102.78  92.67  90.63  83.31  75.5   74.6   76.94  83.04  80.74  80.29
#   82.82  86.29  87.41  85.1   78.08  76.06  69.23  69.04  64.48  65.73
#   67.2   70.25  82.59  92.12 100.82  95.23  89.51  82.84  82.3   83.76
#   84.72  83.91  99.14 101.6  113.03 119.54 118.09 107.32  82.6   77.4
#   71.77  71.25  71.35  73.62  76.2   74.15  75.67  79.2   80.85  85.33
#   75.02  77.95  78.98  76.55  74.89  70.    81.53]

# %%
Kaliningrad[4] = np.mean([Kaliningrad[3],Kaliningrad[6]])

# %%
Kaliningrad[5] = np.mean([Kaliningrad[4],Kaliningrad[6]])

# %%
np.mean(Moscow)
# Out:
# 98.79781609195402

# %%
np.mean(Kaliningrad)
# Out:
# 74.62600574712644

# %%
plt.plot(datas,Moscow)

# %%
x = datas
y = 2*x + 80

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
np.power(Moscow-y,2)
# Out:
# array([5.19840000e+00, 8.52640000e+00, 3.99424000e+01, 6.72400000e+01,
#        8.77969000e+01, 1.25440000e+02, 1.88238400e+02, 2.89340100e+02,
#        4.50712900e+02, 5.71688100e+02, 6.57409600e+02, 7.20385600e+02,
#        8.12250000e+02, 8.39260900e+02, 8.83278400e+02, 1.02080250e+03,
#        1.28809210e+03, 1.52881000e+03, 1.62570240e+03, 1.93160250e+03,
#        2.15946090e+03, 2.56137210e+03, 2.26956960e+03, 1.50854560e+03,
#        6.03684900e+02, 7.38752400e+02, 1.07912250e+03, 1.39651690e+03,
#        1.44704160e+03, 1.82414410e+03, 1.88008960e+03, 1.57926760e+03,
#        1.88095690e+03, 2.43640960e+03, 2.79100890e+03, 2.90628810e+03,
#        2.59386490e+03, 2.09214760e+03, 2.22406560e+03, 2.27719840e+03,
#        2.59081000e+03, 2.90952360e+03, 2.73529000e+03, 3.03821440e+03,
#        4.61312640e+03, 5.84613160e+03, 6.83432890e+03, 7.39772010e+03,
#        7.49263360e+03, 7.48052010e+03, 7.81456000e+03, 8.13964840e+03,
# ...

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 749.2329171225728

# %%
x = datas
y = 0.52*x + 80

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 110.48504740461489

# %%
np.linalg.norm(Moscow-y)
# Out:
# 110.48504740461489

# %%
# Equacao de coeficiente angular
Y = Moscow
X = datas
n = np.size(Moscow)

a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2) - np.sum(X)**2)

# %%
b = np.mean(Y) - a*np.mean(X)

# %%
y = a*X + b

# %%
np.linalg.norm(Moscow-y)
# Out:
# 101.7969539992751

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)
plt.plot(100,100*a+b,'*r')
plt.show()

# %%
np.random.randint(40,100,100)
# Out:
# array([55, 66, 51, 64, 95, 78, 94, 84, 82, 52, 43, 73, 89, 72, 69, 61, 54,
#        60, 44, 60, 98, 58, 99, 95, 74, 60, 93, 54, 77, 86, 86, 98, 75, 93,
#        83, 83, 75, 66, 98, 61, 45, 95, 62, 67, 49, 95, 55, 99, 57, 75, 64,
#        87, 49, 89, 48, 61, 63, 62, 99, 92, 83, 58, 49, 43, 46, 76, 61, 84,
#        89, 61, 99, 68, 74, 84, 64, 50, 43, 80, 71, 73, 72, 88, 50, 92, 94,
#        67, 61, 57, 55, 70, 79, 42, 58, 87, 93, 63, 51, 59, 69, 96])

# %%
b
# Out:
# 79.64892274792834

# %%
coef_angulares = np.random.uniform(0.10,0.90,100)
norma = np.array([])
for i in coef_angulares:
    norma = np.append(norma,np.linalg.norm(Moscow-(i*X+b)))
print(norma)
# Out:
# [101.80666401 181.98833268 119.78540991 102.57070344 120.28828619
#  218.57613638 195.94611262 118.77025274 101.79793784 103.54767489
#  205.17149882 110.72200651 164.16180289 158.13732801 113.91153492
#  161.8546919  156.4090518  102.1137662  116.56841417 193.77722833
#  118.9155346  237.11203069 103.05360114 205.47603339 167.62311344
#  101.83051458 178.33392458 230.349925   112.39085155 174.09264422
#  159.9734045  127.71690394 141.39709719 101.92718876 173.46521075
#  204.44143466 122.38051855 226.17047157 125.67442752 144.16126906
#  235.64281741 146.33820574 133.91010775 110.03518208 156.48618785
#  110.97896281 122.19287342 203.98438855 225.97957501 116.66679181
#  234.3774165  238.16979806 235.00500441 148.45518569 127.89793792
#  101.92905113 206.79549473 149.72052071 107.52178381 199.92279851
#  133.97530141 209.44169567 183.64836553 108.42359459 142.44002245
#  103.5089625  172.89093637 153.60385452 171.49731894 109.20130201
